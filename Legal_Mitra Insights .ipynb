# %%
# Import
import pandas as pd 
import numpy as np 
# Load Dataset
data=pd.read_excel(r"C:\Users\ASUS\OneDrive\Desktop\IP_Filing\IP Data Clean new.xlsx")
data.head()
# Out:
#    Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 0  2024     2024-03-19         2026-05-15    IP-4500       Trade secret
# 1  2023     2023-06-15         2026-09-24    IP-4772          Copyright
# 2  2024     2024-07-08         2031-11-16    IP-6055  Industrial design
# 3  2023     2023-06-18         2031-10-18    IP-4243       Trade secret
# 4  2024     2024-02-22         2026-07-23    IP-8851  Industrial design
#
#   IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# 0               Pending                 499.0                     92.25
# 1              Rejected                 363.0                     43.91
# 2            Registered                 514.0                     82.68
# 3               Pending                 249.0                     86.82
# 4               Pending                 312.0                     74.14
#
#   Rejection_Reasons  Number_of_Opposition_Cases_Received  \
# ...

# %%
# Extract first 5 rows
data.head()
# Out:
#    Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 0  2024     2024-03-19         2026-05-15    IP-4500       Trade secret
# 1  2023     2023-06-15         2026-09-24    IP-4772          Copyright
# 2  2024     2024-07-08         2031-11-16    IP-6055  Industrial design
# 3  2023     2023-06-18         2031-10-18    IP-4243       Trade secret
# 4  2024     2024-02-22         2026-07-23    IP-8851  Industrial design
#
#   IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# 0               Pending                 499.0                     92.25
# 1              Rejected                 363.0                     43.91
# 2            Registered                 514.0                     82.68
# 3               Pending                 249.0                     86.82
# 4               Pending                 312.0                     74.14
#
#   Rejection_Reasons  Number_of_Opposition_Cases_Received  \
# ...

# %%
# Find information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Year                                 1000 non-null   int64
#  1   Date_of_Filing                       1000 non-null   datetime64[ns]
#  2   Date_of_Expiration                   1000 non-null   datetime64[ns]
#  3   IP_Case_ID                           1000 non-null   object
#  4   IP_Type                              1000 non-null   object
#  5   IP_Application_Status                1000 non-null   object
#  6   Processing_Time_Days                 1000 non-null   float64
#  7   Approval_Rate_percentage             1000 non-null   float64
#  8   Rejection_Reasons                    425 non-null    object
#  9   Number_of_Opposition_Cases_Received  1000 non-null   int64
#  10  Number_of_Infringement_Cases         1000 non-null   int64
# ...

# %%
# Export data to the location which are given 
df=pd.DataFrame(data)
df.to_excel(r"C:\Users\ASUS\OneDrive\Desktop\Result of Python.xlsx",sheet_name='Sheet 1',index=False)
print("Process_Completed")
# Out:
# Process_Completed

# %%
# Filter the year to 2023
df1=data[data['Filing_year']==2023]
df1
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 1    2023     2023-06-15         2026-09-24    IP-4772
# 3    2023     2023-06-18         2031-10-18    IP-4243
# 5    2023     2023-11-09         2028-02-11    IP-5351
# 6    2023     2023-01-21         2028-03-19    IP-7589
# 7    2023     2023-04-26         2027-09-11    IP-6447
# ..    ...            ...                ...        ...
# 992  2023     2023-07-27         2030-01-21    IP-3549
# 994  2023     2023-12-18         2029-11-03    IP-7598
# 995  2023     2023-06-14         2025-04-03    IP-4292
# 997  2023     2023-05-06         2028-04-30    IP-5447
# 998  2023     2023-04-08         2030-05-21    IP-5876
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 1                  Copyright              Rejected                 363.0
# 3               Trade secret               Pending                 249.0
# 5                  Trademark               Pending                 633.0
# ...

# %%
# Making the pivot table
df1.pivot_table(index=['Filing_year','IP_Filing_State ','IP_Type'],values='IP_Application_Status',aggfunc='count')
# Out:
#                                                       IP_Application_Status
# Filing_year IP_Filing_State  IP_Type
# 2023        Assam            Copyright                                    6
#                              Geographical indication                      2
#                              Industrial design                            7
#                              Patent                                       4
#                              Trade secret                                 3
# ...                                                                     ...
#             West bengal      Geographical indication                      6
#                              Industrial design                            7
#                              Patent                                       4
#                              Trade secret                                 6
#                              Trademark                                    4
#
# ...

# %%
# Fnding the state which have highest IP filing in 2023 
df1.pivot_table(index="IP_Filing_State ",values='IP_Type',aggfunc='count').sort_values("IP_Type")
# Out:
#                   IP_Type
# IP_Filing_State
# Assam                  26
# Bihar                  30
# Karnataka              31
# Odisha                 31
# Haryana                32
# West bengal            32
# Rajasthan              34
# Telangana              34
# Uttar pradesh          34
# Punjab                 37
# Maharashtra            39
# Tamil nadu             40
# Delhi                  41
# Gujarat                42
# Madhya pradesh         48

# %%
# Filter data where year =2024
df2=data[data['Filing_year']==2024]

# %%
# Making the pivot table for 2024
df2.pivot_table(index="IP_Filing_State ",values='IP_Type',aggfunc='count').sort_values("IP_Type")
# Out:
#                   IP_Type
# IP_Filing_State
# Telangana              20
# Haryana                23
# Maharashtra            27
# Tamil nadu             28
# West bengal            28
# Odisha                 29
# Bihar                  30
# Gujarat                33
# Madhya pradesh         33
# Rajasthan              33
# Punjab                 34
# Delhi                  35
# Uttar pradesh          36
# Assam                  37
# Karnataka              43

# %%
# Pivot table for both of the years (2023-24)
data.pivot_table(index="IP_Filing_State ",values='IP_Type',aggfunc='count').sort_values("IP_Type")
# Out:
#                   IP_Type
# IP_Filing_State
# Telangana              54
# Haryana                55
# Bihar                  60
# Odisha                 60
# West bengal            60
# Assam                  63
# Maharashtra            66
# Rajasthan              67
# Tamil nadu             68
# Uttar pradesh          70
# Punjab                 71
# Karnataka              74
# Gujarat                75
# Delhi                  76
# Madhya pradesh         81

# %%
# Filter where state is Madhyapradesh or Assam
df1a=df1[(df1["IP_Filing_State "]=='Madhya pradesh') | (df1["IP_Filing_State "]=='Assam')]
df1a
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 3    2023     2023-06-18         2031-10-18    IP-4243
# 8    2023     2023-06-12         2025-03-31    IP-5315
# 36   2023     2023-09-22         2033-09-07    IP-5608
# 38   2023     2023-12-04         2026-05-28    IP-1840
# 60   2023     2023-08-17         2027-12-11    IP-5010
# ..    ...            ...                ...        ...
# 949  2023     2023-07-08         2032-11-12    IP-1266
# 959  2023     2023-06-14         2029-05-18    IP-1750
# 962  2023     2023-12-25         2030-08-28    IP-4497
# 988  2023     2023-02-01         2031-03-25    IP-5299
# 997  2023     2023-05-06         2028-04-30    IP-5447
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 3               Trade secret               Pending                 249.0
# 8               Trade secret              Rejected                 351.0
# 36   Geographical indication               Pending                 384.0
# ...

# %%
# Make the pivot table 
df1a.pivot_table(index=["Year","IP_Filing_State "],values="IP_Type",aggfunc='count')
# Out:
#                        IP_Type
# Year IP_Filing_State
# 2023 Assam                  26
#      Madhya pradesh         48

# %%
# Using group by ip type count of state Assam and Madhyapradesh of year2023:-
df1a.groupby(["Year","IP_Filing_State ","IP_Type"])["IP_Type"].agg('count')
# Out:
# Year  IP_Filing_State   IP_Type
# 2023  Assam             Copyright                   6
#                         Geographical indication     2
#                         Industrial design           7
#                         Patent                      4
#                         Trade secret                3
#                         Trademark                   4
#       Madhya pradesh    Copyright                   5
#                         Geographical indication     8
#                         Industrial design          12
#                         Patent                      5
#                         Trade secret                9
#                         Trademark                   9
# Name: IP_Type, dtype: int64

# %%
# Dataset where year ==2024
df2=data[data['Filing_year']==2024]
df2.head()
# Out:
#     Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 0   2024     2024-03-19         2026-05-15    IP-4500
# 2   2024     2024-07-08         2031-11-16    IP-6055
# 4   2024     2024-02-22         2026-07-23    IP-8851
# 9   2024     2024-05-15         2033-06-28    IP-3126
# 11  2024     2024-06-23         2027-02-05    IP-6623
#
#                     IP_Type IP_Application_Status  Processing_Time_Days  \
# 0              Trade secret               Pending                 499.0
# 2         Industrial design            Registered                 514.0
# 4         Industrial design               Pending                 312.0
# 9   Geographical indication              Rejected                 368.5
# 11        Industrial design            Registered                 669.0
#
#     Approval_Rate_percentage Rejection_Reasons  \
# 0                      92.25               NaN
# 2                      82.68               NaN
# 4                      74.14               NaN
# ...

# %%
# Fnding the state which have highest IP filing in 2024

df2.pivot_table(index="IP_Filing_State ",values='IP_Type',aggfunc='count').sort_values("IP_Type")
# Out:
#                   IP_Type
# IP_Filing_State
# Telangana              20
# Haryana                23
# Maharashtra            27
# Tamil nadu             28
# West bengal            28
# Odisha                 29
# Bihar                  30
# Gujarat                33
# Madhya pradesh         33
# Rajasthan              33
# Punjab                 34
# Delhi                  35
# Uttar pradesh          36
# Assam                  37
# Karnataka              43

# %%
# Filter dataset where state are Karnataka or Telangana:-
df2a=df2[(df2["IP_Filing_State "]=='Karnataka') | (df2["IP_Filing_State "]=='Telangana')]
df2a.head()
# Out:
#     Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 2   2024     2024-07-08         2031-11-16    IP-6055
# 24  2024     2024-05-20         2033-04-30    IP-2353
# 37  2024     2024-02-21         2030-08-03    IP-8504
# 66  2024     2024-02-12         2031-03-02    IP-4966
# 76  2024     2024-09-10         2031-09-02    IP-6184
#
#                     IP_Type IP_Application_Status  Processing_Time_Days  \
# 2         Industrial design            Registered                 514.0
# 24  Geographical indication            Registered                 212.0
# 37        Industrial design               Pending                 230.0
# 66  Geographical indication            Registered                 340.0
# 76                Trademark              Rejected                 491.0
#
#     Approval_Rate_percentage Rejection_Reasons  \
# 2                      82.68               NaN
# 24                     72.58               NaN
# 37                     74.95               NaN
# ...

# %%
# Using Group by make the table of Ip type count
df2a.groupby(["Year","IP_Filing_State ","IP_Application_Status","IP_Type"])["IP_Type"].agg('count')
# Out:
# Year  IP_Filing_State   IP_Application_Status  IP_Type
# 2024  Karnataka         Pending                Copyright                  2
#                                                Industrial design          7
#                                                Patent                     1
#                                                Trade secret               6
#                                                Trademark                  3
#                         Registered             Copyright                  1
#                                                Geographical indication    1
#                                                Industrial design          3
#                                                Patent                     2
#                                                Trade secret               1
#                                                Trademark                  2
#                         Rejected               Copyright                  5
# ...

# %%
# Pivot table for the year 2023
df1.pivot_table(index="Filing_Day",values="IP_Type",aggfunc='count').sort_values("IP_Type")
# Out:
#             IP_Type
# Filing_Day
# Tue              62
# Sat              66
# Thu              68
# Mon              78
# Wed              81
# Fri              88
# Sun              88

# %%
# In both Year :- 
m=data.pivot_table(index="Filing_Day",values="IP_Type",aggfunc='count').sort_values("IP_Type")
m
# Out:
#             IP_Type
# Filing_Day
# Sat             125
# Tue             127
# Thu             131
# Mon             145
# Wed             148
# Sun             159
# Fri             165

# %%
# Plot of Filing day
import matplotlib.pyplot as plt
m = m.reset_index()
colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan', 'magenta']

# %%
# m = m.reset_index()
colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan', 'magenta']
bars=plt.bar(m["Filing_Day"],m["IP_Type"],color=colors)
plt.bar_label(bars)
plt.title("Day Wise IP_Filing")
plt.xlabel("Days")
plt.ylabel("Count")
plt.show()

# %%
# In 2024
df2.pivot_table(index="Filing_Day",values="IP_Type",aggfunc='count').sort_values("IP_Type")
# Out:
#             IP_Type
# Filing_Day
# Sat              59
# Thu              63
# Tue              65
# Mon              67
# Wed              67
# Sun              71
# Fri              77

# %%
 # Highest filing Month in 2023
df1.pivot_table(index="Filing_month",values="IP_Type",aggfunc='count').sort_values("IP_Type")
# Out:
#               IP_Type
# Filing_month
# March              35
# September          37
# December           39
# February           39
# January            43
# July               45
# August             46
# October            46
# May                47
# April              50
# November           51
# June               53

# %%
 # Highest filing Month in 2024
df2.pivot_table(index="Filing_month",values="IP_Type",aggfunc='count').sort_values("IP_Type")
# Out:
#               IP_Type
# Filing_month
# May                31
# June               35
# October            35
# December           38
# February           38
# January            38
# April              39
# August             40
# March              40
# July               42
# November           42
# September          51

# %%
#   Month Ip count for both year In Both Year
data.pivot_table(index="Filing_month",values="IP_Type",aggfunc='count').sort_values("IP_Type")
# Out:
#               IP_Type
# Filing_month
# March              75
# December           77
# February           77
# May                78
# January            81
# October            81
# August             86
# July               87
# June               88
# September          88
# April              89
# November           93

# %%
# Extract the first five rows of the data
data.head()
# Out:
#    Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 0  2024     2024-03-19         2026-05-15    IP-4500       Trade secret
# 1  2023     2023-06-15         2026-09-24    IP-4772          Copyright
# 2  2024     2024-07-08         2031-11-16    IP-6055  Industrial design
# 3  2023     2023-06-18         2031-10-18    IP-4243       Trade secret
# 4  2024     2024-02-22         2026-07-23    IP-8851  Industrial design
#
#   IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# 0               Pending                 499.0                     92.25
# 1              Rejected                 363.0                     43.91
# 2            Registered                 514.0                     82.68
# 3               Pending                 249.0                     86.82
# 4               Pending                 312.0                     74.14
#
#   Rejection_Reasons  Number_of_Opposition_Cases_Received  \
# ...

# %%
# Registered IP Filing Dataframe 
df3=data[(data["IP_Application_Status"]=='Registered') & (data["Filing_year"]==2023)]
df3
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 7    2023     2023-04-26         2027-09-11    IP-6447  Industrial design
# 12   2023     2023-02-09         2029-02-27    IP-9657  Industrial design
# 13   2023     2023-12-13         2027-03-04    IP-6880             Patent
# 27   2023     2023-05-14         2031-10-17    IP-9735  Industrial design
# 30   2023     2023-08-16         2026-07-12    IP-3623          Copyright
# ..    ...            ...                ...        ...                ...
# 962  2023     2023-12-25         2030-08-28    IP-4497             Patent
# 966  2023     2023-05-01         2027-08-30    IP-3643             Patent
# 968  2023     2023-01-20         2031-12-26    IP-4224             Patent
# 983  2023     2023-08-25         2026-08-08    IP-1397             Patent
# 988  2023     2023-02-01         2031-03-25    IP-5299             Patent
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# ...

# %%
# using pivot table extract the registration data state wise 
Reg_2023=df3.pivot_table(index=["Filing_year","IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values('IP_Application_Status')
Reg_2023
# Out:
#                               IP_Application_Status
# Filing_year IP_Filing_State
# 2023        West bengal                           5
#             Haryana                               7
#             Punjab                                8
#             Uttar pradesh                         8
#             Karnataka                             9
#             Gujarat                              10
#             Bihar                                11
#             Telangana                            11
#             Maharashtra                          12
#             Odisha                               12
#             Rajasthan                            12
#             Assam                                13
#             Delhi                                13
#             Tamil nadu                           15
#             Madhya pradesh                       18

# %%
# Registered IP Filing DAtaframe 
Reg_2024=data[(data["IP_Application_Status"]=="Registered") & (data["Filing_year"]==2024)]
Reg_2024
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 2    2024     2024-07-08         2031-11-16    IP-6055
# 11   2024     2024-06-23         2027-02-05    IP-6623
# 19   2024     2024-06-14         2026-09-07    IP-1765
# 24   2024     2024-05-20         2033-04-30    IP-2353
# 26   2024     2024-11-10         2030-02-24    IP-5219
# ..    ...            ...                ...        ...
# 980  2024     2024-05-20         2029-04-11    IP-5387
# 982  2024     2024-05-26         2026-08-30    IP-3041
# 986  2024     2024-09-28         2031-08-09    IP-7795
# 993  2024     2024-11-17         2030-10-24    IP-4269
# 999  2024     2024-08-07         2031-12-02    IP-1846
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 2          Industrial design            Registered                 514.0
# 11         Industrial design            Registered                 669.0
# 19                 Copyright            Registered                 403.0
# ...

# %%
# This is the extraction the data with state wise of year 2024
Reg_2024.pivot_table(index=["Year","IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values("IP_Application_Status")
# Out:
#                        IP_Application_Status
# Year IP_Filing_State
# 2024 Madhya pradesh                        4
#      Haryana                               5
#      Odisha                                7
#      Tamil nadu                            7
#      Bihar                                 8
#      Telangana                             8
#      Punjab                                9
#      Karnataka                            10
#      Delhi                                11
#      West bengal                          11
#      Rajasthan                            12
#      Gujarat                              13
#      Maharashtra                          13
#      Uttar pradesh                        13
#      Assam                                14

# %%
''' In 2023 mai madhya pradesh ne sabse jyada ip filing ki this but 2024 mai uski ip filing sabse km ho gyi'''
# Out:
# ' In 2023 mai madhya pradesh ne sabse jyada ip filing ki this but 2024 mai uski ip filing sabse km ho gyi'

# %%
# Extract the dataset where application status  is pending and year is 2023
df4=data[(data["IP_Application_Status"]=='Pending') & (data["Filing_year"]==2023)]
df4
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 3    2023     2023-06-18         2031-10-18    IP-4243
# 5    2023     2023-11-09         2028-02-11    IP-5351
# 22   2023     2023-04-21         2027-02-12    IP-7253
# 28   2023     2023-10-07         2027-02-19    IP-4403
# 36   2023     2023-09-22         2033-09-07    IP-5608
# ..    ...            ...                ...        ...
# 974  2023     2023-01-23         2027-09-26    IP-5365
# 978  2023     2023-12-15         2029-02-22    IP-5625
# 985  2023     2023-08-17         2029-06-19    IP-1555
# 995  2023     2023-06-14         2025-04-03    IP-4292
# 998  2023     2023-04-08         2030-05-21    IP-5876
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 3               Trade secret               Pending                 249.0
# 5                  Trademark               Pending                 633.0
# 22   Geographical indication               Pending                 662.0
# ...

# %%
# Extract pending data state wise of year 2023
Pen_2023=df4.pivot_table(index=["Filing_year","IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values('IP_Application_Status')
Pen_2023
# Out:
#                               IP_Application_Status
# Filing_year IP_Filing_State
# 2023        Assam                                 5
#             Odisha                                5
#             Rajasthan                             9
#             Tamil nadu                           10
#             Punjab                               11
#             Bihar                                12
#             Haryana                              12
#             Karnataka                            13
#             Madhya pradesh                       13
#             Maharashtra                          13
#             Delhi                                15
#             Telangana                            15
#             Uttar pradesh                        15
#             Gujarat                              16
#             West bengal                          17

# %%
# Extract the data e=where application status is pending and year is 2024
df6=data[(data["IP_Application_Status"]=='Pending') & (data["Filing_year"]==2024)]
df6
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 0    2024     2024-03-19         2026-05-15    IP-4500       Trade secret
# 4    2024     2024-02-22         2026-07-23    IP-8851  Industrial design
# 15   2024     2024-07-04         2027-04-08    IP-7448       Trade secret
# 17   2024     2024-01-25         2031-12-07    IP-5282          Copyright
# 21   2024     2024-09-01         2030-06-03    IP-9423       Trade secret
# ..    ...            ...                ...        ...                ...
# 965  2024     2024-03-03         2030-11-13    IP-9146             Patent
# 973  2024     2024-01-01         2026-01-04    IP-8699             Patent
# 976  2024     2024-03-15         2027-05-16    IP-4313             Patent
# 981  2024     2024-06-20         2034-06-18    IP-1140             Patent
# 987  2024     2024-02-14         2033-10-06    IP-7645             Patent
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# ...

# %%
# Make the pivot table to filter some of the records
df6.pivot_table(index=["IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values("IP_Application_Status")
# Out:
#                   IP_Application_Status
# IP_Filing_State
# West bengal                           5
# Maharashtra                           6
# Gujarat                               7
# Assam                                 9
# Telangana                             9
# Bihar                                10
# Uttar pradesh                        10
# Rajasthan                            11
# Haryana                              12
# Odisha                               12
# Delhi                                14
# Punjab                               14
# Tamil nadu                           14
# Madhya pradesh                       18
# Karnataka                            19

# %%
# Extract the dataset where application ststus is reected and year is 2023
df5=data[(data["IP_Application_Status"]=='Rejected') & (data["Filing_year"]==2023)]
df5
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 1    2023     2023-06-15         2026-09-24    IP-4772
# 6    2023     2023-01-21         2028-03-19    IP-7589
# 8    2023     2023-06-12         2025-03-31    IP-5315
# 10   2023     2023-03-17         2027-07-24    IP-4590
# 14   2023     2023-05-24         2026-03-01    IP-1211
# ..    ...            ...                ...        ...
# 989  2023     2023-01-23         2028-08-10    IP-7772
# 990  2023     2023-02-22         2028-07-29    IP-3639
# 992  2023     2023-07-27         2030-01-21    IP-3549
# 994  2023     2023-12-18         2029-11-03    IP-7598
# 997  2023     2023-05-06         2028-04-30    IP-5447
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 1                  Copyright              Rejected                 363.0
# 6    Geographical indication              Rejected                 625.0
# 8               Trade secret              Rejected                 351.0
# ...

# %%
# Using pivot table to extract the application status count state wise.
Rej_2023=df5.pivot_table(index=["Filing_year","IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values('IP_Application_Status')
Rej_2023
# Out:
#                               IP_Application_Status
# Filing_year IP_Filing_State
# 2023        Bihar                                 7
#             Assam                                 8
#             Telangana                             8
#             Karnataka                             9
#             West bengal                          10
#             Uttar pradesh                        11
#             Delhi                                13
#             Haryana                              13
#             Rajasthan                            13
#             Maharashtra                          14
#             Odisha                               14
#             Tamil nadu                           15
#             Gujarat                              16
#             Madhya pradesh                       17
#             Punjab                               18

# %%
# Extract the dataset where application status is rejected and year is 2024
df7=data[(data["IP_Application_Status"]=='Rejected') & (data["Filing_year"]==2024)]
df7
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 9    2024     2024-05-15         2033-06-28    IP-3126
# 18   2024     2024-03-18         2025-08-17    IP-9088
# 20   2024     2024-04-11         2028-09-14    IP-4390
# 29   2024     2024-12-23         2033-12-09    IP-9249
# 48   2024     2024-03-27         2029-04-26    IP-9537
# ..    ...            ...                ...        ...
# 934  2024     2024-02-12         2030-10-20    IP-9676
# 937  2024     2024-09-04         2031-04-24    IP-1472
# 958  2024     2024-05-03         2030-12-10    IP-4485
# 991  2024     2024-05-25         2031-09-13    IP-2606
# 996  2024     2024-11-16         2027-10-07    IP-4565
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 9    Geographical indication              Rejected                 368.5
# 18              Trade secret              Rejected                 325.0
# 20                 Copyright              Rejected                 678.0
# ...

# %%
# Extract the application status count state wise of year 2024
Rej_2024=df7.pivot_table(index=["Filing_year","IP_Filing_State "],values="IP_Application_Status",aggfunc='count').sort_values('IP_Application_Status')
Rej_2024
# Out:
#                               IP_Application_Status
# Filing_year IP_Filing_State
# 2024        Telangana                             3
#             Haryana                               6
#             Tamil nadu                            7
#             Maharashtra                           8
#             Delhi                                10
#             Odisha                               10
#             Rajasthan                            10
#             Madhya pradesh                       11
#             Punjab                               11
#             Bihar                                12
#             West bengal                          12
#             Gujarat                              13
#             Uttar pradesh                        13
#             Assam                                14
#             Karnataka                            14

# %%
# Rejected IP filing state wise both year
y=data.pivot_table(index=["IP_Filing_State "],values="IP_Application_Status",aggfunc='count')
y
# Out:
#                   IP_Application_Status
# IP_Filing_State
# Assam                                63
# Bihar                                60
# Delhi                                76
# Gujarat                              75
# Haryana                              55
# Karnataka                            74
# Madhya pradesh                       81
# Maharashtra                          66
# Odisha                               60
# Punjab                               71
# Rajasthan                            67
# Tamil nadu                           68
# Telangana                            54
# Uttar pradesh                        70
# West bengal                          60

# %%
#  Extract all the columns from the dataset
data.columns
# Out:
# Index(['Year', 'Date_of_Filing', 'Date_of_Expiration', 'IP_Case_ID', 'IP_Type',
#        'IP_Application_Status', 'Processing_Time_Days',
#        'Approval_Rate_percentage', 'Rejection_Reasons',
#        'Number_of_Opposition_Cases_Received', 'Number_of_Infringement_Cases',
#        'IP_Filing_State ', 'Pre_IP_Action_Revenue(INR)',
#        'Post_IP_Action_Revenue(INR)', 'Enforcement_Cost(INR)', 'Filing_Day',
#        'Filing_month', 'Filing_year'],
#       dtype='object')

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Export the data according to the sheet name:-
import pandas as pd
from openpyxl import load_workbook
import pandas as pd

y_df = c.reset_index()

file_path = r"C:\Users\ASUS\OneDrive\Desktop\Result of Python.xlsx"

# Write the DataFrame to the existing Excel file, replacing the sheet if it exists
with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    y_df.to_excel(writer, sheet_name='Sheet1', index=False)

print("Process_Completed")
# Out:
# Process_Completed

# %%
 # dataset
data
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 0    2024     2024-03-19         2026-05-15    IP-4500       Trade secret
# 1    2023     2023-06-15         2026-09-24    IP-4772          Copyright
# 2    2024     2024-07-08         2031-11-16    IP-6055  Industrial design
# 3    2023     2023-06-18         2031-10-18    IP-4243       Trade secret
# 4    2024     2024-02-22         2026-07-23    IP-8851  Industrial design
# ..    ...            ...                ...        ...                ...
# 995  2023     2023-06-14         2025-04-03    IP-4292             Patent
# 996  2024     2024-11-16         2027-10-07    IP-4565             Patent
# 997  2023     2023-05-06         2028-04-30    IP-5447             Patent
# 998  2023     2023-04-08         2030-05-21    IP-5876             Patent
# 999  2024     2024-08-07         2031-12-02    IP-1846             Patent
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# ...

# %%
# Filter the data where the filing year is 2023
df1=data[data['Filing_year']==2023]
df1
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 1    2023     2023-06-15         2026-09-24    IP-4772
# 3    2023     2023-06-18         2031-10-18    IP-4243
# 5    2023     2023-11-09         2028-02-11    IP-5351
# 6    2023     2023-01-21         2028-03-19    IP-7589
# 7    2023     2023-04-26         2027-09-11    IP-6447
# ..    ...            ...                ...        ...
# 992  2023     2023-07-27         2030-01-21    IP-3549
# 994  2023     2023-12-18         2029-11-03    IP-7598
# 995  2023     2023-06-14         2025-04-03    IP-4292
# 997  2023     2023-05-06         2028-04-30    IP-5447
# 998  2023     2023-04-08         2030-05-21    IP-5876
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 1                  Copyright              Rejected                 363.0
# 3               Trade secret               Pending                 249.0
# 5                  Trademark               Pending                 633.0
# ...

# %%
# Filter the data where application status is rejected and year is 2023
m=df1[df1["IP_Application_Status"]=='Rejected']
m
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID  \
# 1    2023     2023-06-15         2026-09-24    IP-4772
# 6    2023     2023-01-21         2028-03-19    IP-7589
# 8    2023     2023-06-12         2025-03-31    IP-5315
# 10   2023     2023-03-17         2027-07-24    IP-4590
# 14   2023     2023-05-24         2026-03-01    IP-1211
# ..    ...            ...                ...        ...
# 989  2023     2023-01-23         2028-08-10    IP-7772
# 990  2023     2023-02-22         2028-07-29    IP-3639
# 992  2023     2023-07-27         2030-01-21    IP-3549
# 994  2023     2023-12-18         2029-11-03    IP-7598
# 997  2023     2023-05-06         2028-04-30    IP-5447
#
#                      IP_Type IP_Application_Status  Processing_Time_Days  \
# 1                  Copyright              Rejected                 363.0
# 6    Geographical indication              Rejected                 625.0
# 8               Trade secret              Rejected                 351.0
# ...

# %%
making the pivot table to extract the aoplication status count according the month
c=m.pivot_table(index="Filing_month",values="IP_Application_Status",aggfunc='count')
c
# Out:
#               IP_Application_Status
# Filing_month
# April                            11
# August                           13
# December                         16
# February                         20
# January                          17
# July                             14
# June                             19
# March                            14
# May                              14
# November                         19
# October                          17
# September                        12

# %%
# Checking the IP Type filing in march month
df9=data[data["Filing_month"]=="March"]
df9
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID       IP_Type  \
# 0    2024     2024-03-19         2026-05-15    IP-4500  Trade secret
# 10   2023     2023-03-17         2027-07-24    IP-4590     Copyright
# 18   2024     2024-03-18         2025-08-17    IP-9088  Trade secret
# 32   2023     2023-03-12         2030-06-03    IP-4523  Trade secret
# 33   2023     2023-03-04         2027-03-27    IP-5892  Trade secret
# ..    ...            ...                ...        ...           ...
# 910  2024     2024-03-28         2031-10-22    IP-7721     Trademark
# 935  2024     2024-03-17         2025-09-24    IP-6697        Patent
# 940  2024     2024-03-23         2033-02-22    IP-9846        Patent
# 965  2024     2024-03-03         2030-11-13    IP-9146        Patent
# 976  2024     2024-03-15         2027-05-16    IP-4313        Patent
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# ...

# %%
# Extract the IP_Type count where the filing month is March
m=df9.groupby("IP_Type")["Filing_month"].agg('count')
m
# Out:
# IP_Type
# Copyright                  14
# Geographical indication    14
# Industrial design           8
# Patent                      9
# Trade secret               18
# Trademark                  12
# Name: Filing_month, dtype: int64

# %%
# Import data according the sheet name 
import pandas as pd
from openpyxl import load_workbook
import pandas as pd

y_df =m .reset_index()

file_path = r"C:\Users\ASUS\OneDrive\Desktop\Result of Python.xlsx"

# Write the DataFrame to the existing Excel file, replacing the sheet if it exists
with pd.ExcelWriter(file_path, engine='openpyxl', mode='a', if_sheet_exists='replace') as writer:
    y_df.to_excel(writer, sheet_name='Sheet1', index=False)

print("Process_Completed")
# Out:
# Process_Completed

# %%
# Extract the data where filing month is March
df10=data[(data["Filing_month"]=='March')]
df10
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID       IP_Type  \
# 0    2024     2024-03-19         2026-05-15    IP-4500  Trade secret
# 10   2023     2023-03-17         2027-07-24    IP-4590     Copyright
# 18   2024     2024-03-18         2025-08-17    IP-9088  Trade secret
# 32   2023     2023-03-12         2030-06-03    IP-4523  Trade secret
# 33   2023     2023-03-04         2027-03-27    IP-5892  Trade secret
# ..    ...            ...                ...        ...           ...
# 910  2024     2024-03-28         2031-10-22    IP-7721     Trademark
# 935  2024     2024-03-17         2025-09-24    IP-6697        Patent
# 940  2024     2024-03-23         2033-02-22    IP-9846        Patent
# 965  2024     2024-03-03         2030-11-13    IP-9146        Patent
# 976  2024     2024-03-15         2027-05-16    IP-4313        Patent
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# ...

# %%
# Extract the data where IP_Type is Indrustrial design
v=df10[df10["IP_Type"]=="Industrial design"]
v
# Out:
#      Year Date_of_Filing Date_of_Expiration IP_Case_ID            IP_Type  \
# 157  2024     2024-03-03         2031-12-20    IP-3157  Industrial design
# 218  2023     2023-03-06         2030-03-16    IP-4764  Industrial design
# 275  2024     2024-03-01         2029-09-30    IP-4246  Industrial design
# 346  2023     2023-03-09         2030-04-30    IP-9786  Industrial design
# 389  2024     2024-03-08         2030-04-27    IP-7990  Industrial design
# 430  2024     2024-03-27         2027-10-14    IP-3726  Industrial design
# 767  2023     2023-03-07         2029-01-17    IP-4890  Industrial design
# 796  2023     2023-03-06         2028-06-06    IP-8251  Industrial design
#
#     IP_Application_Status  Processing_Time_Days  Approval_Rate_percentage  \
# 157            Registered                 562.0                     94.63
# 218            Registered                 445.0                     62.62
# 275              Rejected                 571.0                     74.85
# ...

# %%
# Extract the ip filing count of the v dataset
v.pivot_table(index="Filing_year",values="IP_Type",aggfunc='count')
# Out:
#              IP_Type
# Filing_year
# 2023               4
# 2024               4

# %%
import matplotlib.pyplot as plt

# %%
# Making the pie chart between 2023 and 2024 march month indrustrial design ip
pivot_df = v.pivot_table(index="Filing_year", values="IP_Type", aggfunc='count')
pivot_df.plot.pie(
    y='IP_Type',
    labels=pivot_df.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Industrial_design [March]")
plt.ylabel("")
plt.show()
